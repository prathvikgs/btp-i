# %% [markdown]
# # PI-Deeponet

# %% [markdown]
# $$\frac{\partial s}{\partial t} = D_{coeff}\frac{\partial^2 s}{\partial x^2} + K_{coeff}s^2 + u(x)$$\
# $$s(x,0) = 0$$
#
#
# boundary condition: periodic\
# $domain$ : $$x = [0,1],t = [0,1]$$

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, concatenate, Lambda
from tensorflow.keras.utils import to_categorical
import scipy.io
import time as time_lib
import scipy.optimize
from scipy.fft import fft, ifft
from scipy.integrate import odeint
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ##Training Data preparation

# %%
n_functions=50 #no of functions
n_sensors=100 #no of sensor points

lb_A=-1 #lowerbound of coefficient
ub_A=1 #upperbound of coefficient
L=1
nx = 50 # no of grid points for x
nt = 50 # no of grid points for t

n_bdr=400
n_train=nx*nt

# domain
x_0=0
x_l=1
t_0=0
t_l=1

#for trunck-inside points
x=np.linspace(x_0,x_l,nx)
t=np.linspace(t_0,t_l,nt)

#boundary points 1 (t=0)
x_bdr=np.random.rand(n_bdr)
t_bdr=np.zeros(n_bdr)

#boundary points 2 (x=0 and x=L)
x_bdr2=np.zeros(n_bdr)
t_bdr2=np.random.rand(n_bdr)

#for trunck
x_sensor=np.linspace(0,1,n_sensors)

t=np.reshape(t,(len(t),1))
x=np.reshape(x,(len(x),1))

x_eval,t_eval = np.meshgrid(x,t)
x_eval=np.reshape(x_eval,-1)
t_eval=np.reshape(t_eval,-1)

x_bdr=np.reshape(x_bdr,-1)
t_bdr=np.reshape(t_bdr,-1)

x_bdr2=np.reshape(x_bdr2,-1)
t_bdr2=np.reshape(t_bdr2,-1)

y=np.concatenate([x_eval[:, None], t_eval[:, None]],axis=1)
y_bdr=np.concatenate([x_bdr[:, None], t_bdr[:, None]],axis=1)
y_bdr2=np.concatenate([x_bdr2[:, None], t_bdr2[:, None]],axis=1)

A=np.random.rand(n_functions)
B=np.random.rand(n_functions)

D_coeff  = 0.01 # constant in PDE
K_coeff = 0.01 # constant in PDE

#functions
def fn(A,B,x):
    return np.cos(2*np.pi*A*x)+np.sin(2*np.pi*B*x)+A*np.e**(-A*x)-B*np.e**(B*x)+np.log(1+A)+B*A*np.log(1+A*B)#+(A*B*x**2+x+B+A*B**2)**2+A*x+B*x**2+A+B
#DNS
def sol_reaction_diff(u,t,K_coeff,D_coeff):

    s_0 = u*0.0

    def rhsf(s, t):
        N = len(s)
        n = np.arange(N); n[int(N/2)+1:]-= N
        return K_coeff*s**2 - D_coeff*ifft((2*np.pi*n/L)**2*fft(s)).real + u
    sol = odeint(rhsf, s_0, t)

    return sol

f=[]
for i in range(n_functions):
    f.append(fn(A[i],B[i],x_sensor))

f=np.array(f)

# %%
f.shape
# Out:
# (50, 100)

# %%
#create X_train

#x_branch and x_branch to train
X_train_branch=[]
X_train_trunck=[]
A_train=[]
B_train=[]

for i in range(n_functions):
    for j in range(n_train):
        X_train_branch.append(f[i])
        X_train_trunck.append(y[j])

        A_train.append(A[i])
        B_train.append(B[i])

X_train_branch=np.array(X_train_branch)
X_train_trunck=np.array(X_train_trunck)

A_train=np.array(A_train)
B_train=np.array(B_train)

#create X_train for boundary (t=0)

#x_branch and x_branch to train
X_train_branch_bdr=[]
X_train_trunck_bdr=[]
A_train_bdr=[]
B_train_bdr=[]

for i in range(n_functions):
    for j in range(n_bdr):
        X_train_branch_bdr.append(f[i])
        X_train_trunck_bdr.append(y_bdr[j])

        A_train_bdr.append(A[i])
        B_train_bdr.append(B[i])

X_train_branch_bdr=np.array(X_train_branch_bdr)
X_train_trunck_bdr=np.array(X_train_trunck_bdr)

A_train_bdr=np.array(A_train_bdr)
B_train_bdr=np.array(B_train_bdr)

#create X_train for boundary(x=0 )

#x_branch and x_branch to train
X_train_branch_bdr2=[]
X_train_trunck_bdr2=[]
A_train_bdr2=[]
B_train_bdr2=[]

for i in range(n_functions):
    for j in range(n_bdr):
        X_train_branch_bdr2.append(f[i])
        X_train_trunck_bdr2.append(y_bdr2[j])

        A_train_bdr2.append(A[i])
        B_train_bdr2.append(B[i])

X_train_branch_bdr2=np.array(X_train_branch_bdr2)
X_train_trunck_bdr2=np.array(X_train_trunck_bdr2)

A_train_bdr2=np.array(A_train_bdr2)
B_train_bdr2=np.array(B_train_bdr2)

# %%
X_train_br=tf.convert_to_tensor(X_train_branch, dtype=tf.float32, dtype_hint=None, name=None)
X_train_tr=tf.convert_to_tensor(X_train_trunck, dtype=tf.float32, dtype_hint=None, name=None)
A_train=tf.convert_to_tensor(A_train, dtype=tf.float32, dtype_hint=None, name=None)
B_train=tf.convert_to_tensor(B_train, dtype=tf.float32, dtype_hint=None, name=None)

X_train_br_bdr=tf.convert_to_tensor(X_train_branch_bdr, dtype=tf.float32, dtype_hint=None, name=None)
X_train_tr_bdr=tf.convert_to_tensor(X_train_trunck_bdr, dtype=tf.float32, dtype_hint=None, name=None)
A_train_bdr=tf.convert_to_tensor(A_train_bdr, dtype=tf.float32, dtype_hint=None, name=None)
B_train_bdr=tf.convert_to_tensor(B_train_bdr, dtype=tf.float32, dtype_hint=None, name=None)

X_train_br_bdr2=tf.convert_to_tensor(X_train_branch_bdr2, dtype=tf.float32, dtype_hint=None, name=None)
X_train_tr_bdr2=tf.convert_to_tensor(X_train_trunck_bdr2, dtype=tf.float32, dtype_hint=None, name=None)
A_train_bdr2=tf.convert_to_tensor(A_train_bdr2, dtype=tf.float32, dtype_hint=None, name=None)
B_train_bdr2=tf.convert_to_tensor(B_train_bdr2, dtype=tf.float32, dtype_hint=None, name=None)

# %%
dataset = tf.data.Dataset.from_tensor_slices((X_train_br, X_train_tr, A_train,B_train))
dataset_bdr=tf.data.Dataset.from_tensor_slices((X_train_br_bdr, X_train_tr_bdr, A_train_bdr,B_train_bdr))
dataset_bdr2=tf.data.Dataset.from_tensor_slices((X_train_br_bdr2, X_train_tr_bdr2, A_train_bdr2,B_train_bdr2))

batch_size = 25000  # Adjust this based on needs
batch_size_bdr = 4000
batch_size_bdr2 = 4000

dataset = dataset.batch(batch_size)
dataset_bdr = dataset_bdr.batch(batch_size_bdr)
dataset_bdr2 = dataset_bdr2.batch(batch_size_bdr2)

# %% [markdown]
# ## DeepOnet mdoel Architecture and PINN Loss

# %%
# Define the optimizer
optimizer = tf.keras.optimizers.Adam()
tf.keras.backend.set_floatx('float32')

#model for deepOnet###########################################################

#no of sensor points
m=n_sensors
branch_input = Input(shape=(m,), name='vector_input')
trunck_input = Input(shape=(2,), name='scalar_input')

#branch network
branch_net = Dense(128, activation='tanh')(branch_input)
branch_net = Dense(128, activation='tanh')(branch_net)
branch_net = Dense(128, activation='tanh')(branch_net)
branch_net = Dense(128, activation='tanh')(branch_net)
branch_net = Dense(128, activation='tanh')(branch_net)
branch_net = Dense(128, activation='tanh')(branch_net)
branch_net = Dense(m, activation='tanh')(branch_net)

# Trunck network
trunck_net = Dense(128, activation='tanh')(trunck_input)
trunck_net = Dense(128, activation='tanh')(trunck_net)
trunck_net = Dense(128, activation='tanh')(trunck_net)
trunck_net = Dense(128, activation='tanh')(trunck_net)
trunck_net = Dense(128, activation='tanh')(trunck_net)
trunck_net = Dense(128, activation='tanh')(trunck_net)
trunck_net = Dense(m, activation='tanh')(trunck_net)
#bias = tf.Variable(0., shape=(), trainable=True)

dot_product = Lambda(lambda x: tf.reduce_sum(x[0] * x[1], axis=1, keepdims=True))([branch_net, trunck_net])
model = tf.keras.Model(inputs=[branch_input, trunck_input], outputs=dot_product)

############################# Loss Functions ##################################################

def loss(X_br,X_tr,A,B):
    with tf.GradientTape(persistent=True) as tape:

            x,t=tf.unstack(X_tr,axis=1)
            tape.watch(x)
            tape.watch(t)

            s = model([X_br, tf.stack((x,t),axis=1)], training=True)
            dsdx=tape.gradient(s,x)
            d2sdx2=tape.gradient(dsdx,x)

            dsdt=tape.gradient(s,t)
            u=fn(A,B,x)

            loss = tf.reduce_mean(tf.square(dsdt-D_coeff*d2sdx2-K_coeff*tf.square(s)-u))

    return loss

def loss_bdr(X_br,X_tr,A,B):
    with tf.GradientTape(persistent=True) as tape:

            x,t=tf.unstack(X_tr,axis=1)
            tape.watch(x)
            tape.watch(t)

            s = model([X_br, tf.stack((x,t),axis=1)], training=True)
            dsdx=tape.gradient(s,x)
            d2sdx2=tape.gradient(dsdx,x)

            dsdt=tape.gradient(s,t)
            u=fn(A,B,x)

            loss2=tf.reduce_mean(tf.square(s))#initial loss
            loss = tf.reduce_mean(tf.square(dsdt-D_coeff*d2sdx2-K_coeff*tf.square(s)-u))#equation loss

    return (loss+loss2)/2

def loss_bdr2(X_br,X_tr,A,B):
    with tf.GradientTape(persistent=True) as tape:

            x,t=tf.unstack(X_tr,axis=1)
            xl=x+L
            tape.watch(x)
            tape.watch(t)
            tape.watch(xl)
            
            s = model([X_br, tf.stack((x,t),axis=1)], training=True)
            s1 = model([X_br, tf.stack((xl,t),axis=1)], training=True)
            
            dsdx=tape.gradient(s,x)
            d2sdx2=tape.gradient(dsdx,x)
            
            ds1dx=tape.gradient(s1,xl)
            d2s1dx2=tape.gradient(ds1dx,xl)

            dsdt=tape.gradient(s,t)
            ds1dt=tape.gradient(s1,t)
            
            u=fn(A,B,x)
            
            loss_bdr=tf.reduce_mean(tf.square(s-s1))
            loss_bdr_2=tf.reduce_mean(tf.square(dsdx-ds1dx))
            
            loss1 = tf.reduce_mean(tf.square(dsdt-D_coeff*d2sdx2-K_coeff*tf.square(s)-u))#equation loss at x=0
            loss2 = tf.reduce_mean(tf.square(ds1dt-D_coeff*d2s1dx2-K_coeff*tf.square(s1)-u))#equation loss at x=L
            
            
    return (loss_bdr+loss_bdr_2+loss1+loss2)/4

# %% [markdown]
# ##Training LOOP

# %%
# Training loop

# Define a learning rate schedule
initial_learning_rate = 1e-3
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100, decay_rate=0.9)

# Define the optimizer with the learning rate schedule
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

loss_total=[]
epochs=[]
for epoch in range(600):
    for X_br, X_tr, A,B in dataset:
        with tf.GradientTape() as tape:

            loss_value = loss(X_br,X_tr,A,B)
        grads = tape.gradient(loss_value, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))

    for X_br, X_tr, A,B in dataset_bdr:
        with tf.GradientTape() as tape:

            loss_value_bdr = loss_bdr(X_br,X_tr,A,B)
        grads = tape.gradient(loss_value_bdr, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))

    #loss_total.append(loss_value+loss_value_bdr)
    #epochs.append(epoch)
    
    for X_br, X_tr, A,B in dataset_bdr2:
        with tf.GradientTape() as tape:
            loss_value_bdr2 = loss_bdr2(X_br,X_tr,A,B)
        grads = tape.gradient(loss_value_bdr2, model.trainable_variables)
        optimizer.apply_gradients(zip(grads, model.trainable_variables))
       
    loss_total_f=(loss_value+loss_value_bdr+loss_value_bdr2)/3
    loss_total.append(loss_total_f)
    epochs.append(epoch)
    
    if epoch % 1 == 0:
        print(f"Epoch {epoch}, loss={loss_total_f:.6f}")
    #print(f"Epoch {epoch}, loss={loss_value:.6f}", end='\r')
# Out:
# Epoch 0, loss=0.829856
# Epoch 1, loss=0.624198
# Epoch 2, loss=0.581548
# Epoch 3, loss=0.516384
# Epoch 4, loss=0.566558
# Epoch 5, loss=0.566055
# Epoch 6, loss=0.572615
# Epoch 7, loss=0.588709
# Epoch 8, loss=0.573814
# Epoch 9, loss=0.517920
# Epoch 10, loss=0.583002
# Epoch 11, loss=0.601524
# Epoch 12, loss=0.566705
# Epoch 13, loss=0.534646
# Epoch 14, loss=0.626469
# Epoch 15, loss=0.616658
# Epoch 16, loss=0.618012
# Epoch 17, loss=0.562558
# Epoch 18, loss=0.555294
# Epoch 19, loss=0.585934
# Epoch 20, loss=0.586383
# Epoch 21, loss=0.592572
# Epoch 22, loss=0.514840
# Epoch 23, loss=0.495383
# Epoch 24, loss=0.533115
# Epoch 25, loss=0.485701
# Epoch 26, loss=0.487198
# Epoch 27, loss=0.511284
# Epoch 28, loss=0.500732
# Epoch 29, loss=0.465977
# Epoch 30, loss=0.510832
# Epoch 31, loss=0.565931
# Epoch 32, loss=0.525309
# Epoch 33, loss=0.598981
# Epoch 34, loss=0.563532
# Epoch 35, loss=0.528186
# Epoch 36, loss=0.484889
# Epoch 37, loss=0.506989
# Epoch 38, loss=0.497805
# Epoch 39, loss=0.505412
# Epoch 40, loss=0.488137
# Epoch 41, loss=0.476817
# Epoch 42, loss=0.493786
# Epoch 43, loss=0.486806
# Epoch 44, loss=0.446279
# Epoch 45, loss=0.451892
# Epoch 46, loss=0.491997
# Epoch 47, loss=0.450336
# Epoch 48, loss=0.436001
# Epoch 49, loss=0.471890
# Epoch 50, loss=0.434279
# Epoch 51, loss=0.461692
# Epoch 52, loss=0.445053
# Epoch 53, loss=0.458846
# Epoch 54, loss=0.415158
# Epoch 55, loss=0.424863
# Epoch 56, loss=0.411945
# Epoch 57, loss=0.421156
# Epoch 58, loss=0.436821
# Epoch 59, loss=0.434047
# Epoch 60, loss=0.408669
# Epoch 61, loss=0.431668
# Epoch 62, loss=0.406732
# Epoch 63, loss=0.432493
# Epoch 64, loss=0.401764
# Epoch 65, loss=0.413688
# Epoch 66, loss=0.369230
# Epoch 67, loss=0.392847
# Epoch 68, loss=0.375975
# Epoch 69, loss=0.388713
# Epoch 70, loss=0.377564
# Epoch 71, loss=0.401461
# Epoch 72, loss=0.394289
# Epoch 73, loss=0.401311
# Epoch 74, loss=0.354609
# Epoch 75, loss=0.382730
# Epoch 76, loss=0.353872
# Epoch 77, loss=0.367845
# Epoch 78, loss=0.345731
# Epoch 79, loss=0.362216
# Epoch 80, loss=0.344171
# Epoch 81, loss=0.373156
# Epoch 82, loss=0.343357
# Epoch 83, loss=0.371915
# Epoch 84, loss=0.339219
# Epoch 85, loss=0.356828
# Epoch 86, loss=0.317072
# Epoch 87, loss=0.339347
# Epoch 88, loss=0.308724
# Epoch 89, loss=0.332419
# Epoch 90, loss=0.302560
# Epoch 91, loss=0.338040
# Epoch 92, loss=0.300744
# Epoch 93, loss=0.348223
# Epoch 94, loss=0.297997
# Epoch 95, loss=0.337343
# Epoch 96, loss=0.294727
# Epoch 97, loss=0.325767
# Epoch 98, loss=0.285993
# Epoch 99, loss=0.326010
# Epoch 100, loss=0.285445
# Epoch 101, loss=0.326236
# Epoch 102, loss=0.278965
# Epoch 103, loss=0.303671
# Epoch 104, loss=0.269111
# Epoch 105, loss=0.297068
# Epoch 106, loss=0.270028
# Epoch 107, loss=0.300392
# Epoch 108, loss=0.272935
# Epoch 109, loss=0.310725
# Epoch 110, loss=0.274363
# Epoch 111, loss=0.307703
# Epoch 112, loss=0.266291
# Epoch 113, loss=0.290722
# Epoch 114, loss=0.260173
# Epoch 115, loss=0.276310
# Epoch 116, loss=0.258693
# Epoch 117, loss=0.267218
# Epoch 118, loss=0.259480
# Epoch 119, loss=0.262037
# Epoch 120, loss=0.261707
# Epoch 121, loss=0.260769
# Epoch 122, loss=0.268161
# Epoch 123, loss=0.266255
# Epoch 124, loss=0.276417
# Epoch 125, loss=0.259368
# Epoch 126, loss=0.268891
# Epoch 127, loss=0.256085
# Epoch 128, loss=0.263557
# Epoch 129, loss=0.252197
# Epoch 130, loss=0.262747
# Epoch 131, loss=0.247374
# Epoch 132, loss=0.262402
# Epoch 133, loss=0.242648
# Epoch 134, loss=0.257053
# Epoch 135, loss=0.239438
# Epoch 136, loss=0.250742
# Epoch 137, loss=0.238622
# Epoch 138, loss=0.245475
# Epoch 139, loss=0.238805
# Epoch 140, loss=0.241619
# Epoch 141, loss=0.238587
# Epoch 142, loss=0.238902
# Epoch 143, loss=0.237735
# Epoch 144, loss=0.236862
# Epoch 145, loss=0.236813
# Epoch 146, loss=0.234670
# Epoch 147, loss=0.236941
# Epoch 148, loss=0.231860
# Epoch 149, loss=0.239614
# Epoch 150, loss=0.229380
# Epoch 151, loss=0.245708
# Epoch 152, loss=0.229672
# Epoch 153, loss=0.253588
# Epoch 154, loss=0.233995
# Epoch 155, loss=0.255467
# Epoch 156, loss=0.235454
# Epoch 157, loss=0.245715
# Epoch 158, loss=0.230751
# Epoch 159, loss=0.237049
# Epoch 160, loss=0.226774
# Epoch 161, loss=0.232611
# Epoch 162, loss=0.224174
# Epoch 163, loss=0.228612
# Epoch 164, loss=0.222986
# Epoch 165, loss=0.225649
# Epoch 166, loss=0.222613
# Epoch 167, loss=0.223696
# Epoch 168, loss=0.222209
# Epoch 169, loss=0.222290
# Epoch 170, loss=0.221659
# Epoch 171, loss=0.221151
# Epoch 172, loss=0.220982
# Epoch 173, loss=0.220171
# Epoch 174, loss=0.220188
# Epoch 175, loss=0.219298
# Epoch 176, loss=0.219301
# Epoch 177, loss=0.218487
# Epoch 178, loss=0.218370
# Epoch 179, loss=0.217701
# Epoch 180, loss=0.217439
# Epoch 181, loss=0.216908
# Epoch 182, loss=0.216538
# Epoch 183, loss=0.216093
# Epoch 184, loss=0.215673
# Epoch 185, loss=0.215258
# Epoch 186, loss=0.214834
# Epoch 187, loss=0.214416
# Epoch 188, loss=0.214009
# Epoch 189, loss=0.213581
# Epoch 190, loss=0.213188
# Epoch 191, loss=0.212758
# Epoch 192, loss=0.212371
# Epoch 193, loss=0.211947
# Epoch 194, loss=0.211559
# Epoch 195, loss=0.211146
# Epoch 196, loss=0.210757
# Epoch 197, loss=0.210353
# Epoch 198, loss=0.209964
# Epoch 199, loss=0.209568
# Epoch 200, loss=0.209183
# Epoch 201, loss=0.208792
# Epoch 202, loss=0.208411
# Epoch 203, loss=0.208026
# Epoch 204, loss=0.207650
# Epoch 205, loss=0.207270
# Epoch 206, loss=0.206898
# Epoch 207, loss=0.206525
# Epoch 208, loss=0.206157
# Epoch 209, loss=0.205790
# Epoch 210, loss=0.205427
# Epoch 211, loss=0.205065
# Epoch 212, loss=0.204707
# Epoch 213, loss=0.204351
# Epoch 214, loss=0.203999
# Epoch 215, loss=0.203648
# Epoch 216, loss=0.203301
# Epoch 217, loss=0.202956
# Epoch 218, loss=0.202615
# Epoch 219, loss=0.202276
# Epoch 220, loss=0.201940
# Epoch 221, loss=0.201606
# Epoch 222, loss=0.201276
# Epoch 223, loss=0.200948
# Epoch 224, loss=0.200623
# Epoch 225, loss=0.200301
# Epoch 226, loss=0.199982
# Epoch 227, loss=0.199666
# Epoch 228, loss=0.199352
# Epoch 229, loss=0.199041
# Epoch 230, loss=0.198734
# Epoch 231, loss=0.198429
# Epoch 232, loss=0.198127
# Epoch 233, loss=0.197828
# Epoch 234, loss=0.197531
# Epoch 235, loss=0.197238
# Epoch 236, loss=0.196947
# Epoch 237, loss=0.196659
# Epoch 238, loss=0.196374
# Epoch 239, loss=0.196092
# Epoch 240, loss=0.195813
# Epoch 241, loss=0.195537
# Epoch 242, loss=0.195263
# Epoch 243, loss=0.194992
# Epoch 244, loss=0.194724
# Epoch 245, loss=0.194459
# Epoch 246, loss=0.194196
# Epoch 247, loss=0.193936
# Epoch 248, loss=0.193679
# Epoch 249, loss=0.193425
# Epoch 250, loss=0.193174
# Epoch 251, loss=0.192925
# Epoch 252, loss=0.192679
# Epoch 253, loss=0.192435
# Epoch 254, loss=0.192195
# Epoch 255, loss=0.191956
# Epoch 256, loss=0.191721
# Epoch 257, loss=0.191488
# Epoch 258, loss=0.191258
# Epoch 259, loss=0.191030
# Epoch 260, loss=0.190805
# Epoch 261, loss=0.190583
# Epoch 262, loss=0.190363
# Epoch 263, loss=0.190145
# Epoch 264, loss=0.189931
# Epoch 265, loss=0.189718
# Epoch 266, loss=0.189508
# Epoch 267, loss=0.189301
# Epoch 268, loss=0.189096
# Epoch 269, loss=0.188893
# Epoch 270, loss=0.188693
# Epoch 271, loss=0.188495
# Epoch 272, loss=0.188300
# Epoch 273, loss=0.188107
# Epoch 274, loss=0.187916
# Epoch 275, loss=0.187727
# Epoch 276, loss=0.187541
# Epoch 277, loss=0.187357
# Epoch 278, loss=0.187176
# Epoch 279, loss=0.186996
# Epoch 280, loss=0.186819
# Epoch 281, loss=0.186644
# Epoch 282, loss=0.186471
# Epoch 283, loss=0.186301
# Epoch 284, loss=0.186132
# Epoch 285, loss=0.185966
# Epoch 286, loss=0.185801
# Epoch 287, loss=0.185639
# Epoch 288, loss=0.185479
# Epoch 289, loss=0.185320
# Epoch 290, loss=0.185164
# Epoch 291, loss=0.185010
# Epoch 292, loss=0.184858
# Epoch 293, loss=0.184708
# Epoch 294, loss=0.184559
# Epoch 295, loss=0.184413
# Epoch 296, loss=0.184268
# Epoch 297, loss=0.184126
# Epoch 298, loss=0.183985
# Epoch 299, loss=0.183846
# Epoch 300, loss=0.183709
# Epoch 301, loss=0.183573
# Epoch 302, loss=0.183440
# Epoch 303, loss=0.183308
# Epoch 304, loss=0.183178
# Epoch 305, loss=0.183049
# Epoch 306, loss=0.182923
# Epoch 307, loss=0.182798
# Epoch 308, loss=0.182674
# Epoch 309, loss=0.182553
# Epoch 310, loss=0.182432
# Epoch 311, loss=0.182314
# Epoch 312, loss=0.182197
# Epoch 313, loss=0.182082
# Epoch 314, loss=0.181968
# Epoch 315, loss=0.181856
# Epoch 316, loss=0.181745
# Epoch 317, loss=0.181636
# Epoch 318, loss=0.181528
# Epoch 319, loss=0.181422
# Epoch 320, loss=0.181317
# Epoch 321, loss=0.181214
# Epoch 322, loss=0.181112
# Epoch 323, loss=0.181011
# Epoch 324, loss=0.180912
# Epoch 325, loss=0.180814
# Epoch 326, loss=0.180717
# Epoch 327, loss=0.180622
# Epoch 328, loss=0.180528
# Epoch 329, loss=0.180436
# Epoch 330, loss=0.180344
# Epoch 331, loss=0.180254
# Epoch 332, loss=0.180166
# Epoch 333, loss=0.180078
# Epoch 334, loss=0.179992
# Epoch 335, loss=0.179907
# Epoch 336, loss=0.179823
# Epoch 337, loss=0.179740
# Epoch 338, loss=0.179658
# Epoch 339, loss=0.179578
# Epoch 340, loss=0.179498
# Epoch 341, loss=0.179420
# Epoch 342, loss=0.179343
# Epoch 343, loss=0.179267
# Epoch 344, loss=0.179192
# Epoch 345, loss=0.179118
# Epoch 346, loss=0.179045
# Epoch 347, loss=0.178973
# Epoch 348, loss=0.178902
# Epoch 349, loss=0.178832
# Epoch 350, loss=0.178764
# Epoch 351, loss=0.178696
# Epoch 352, loss=0.178629
# Epoch 353, loss=0.178563
# Epoch 354, loss=0.178498
# Epoch 355, loss=0.178434
# Epoch 356, loss=0.178370
# Epoch 357, loss=0.178308
# Epoch 358, loss=0.178247
# Epoch 359, loss=0.178186
# Epoch 360, loss=0.178127
# Epoch 361, loss=0.178068
# Epoch 362, loss=0.178010
# Epoch 363, loss=0.177953
# Epoch 364, loss=0.177896
# Epoch 365, loss=0.177841
# Epoch 366, loss=0.177786
# Epoch 367, loss=0.177732
# Epoch 368, loss=0.177679
# Epoch 369, loss=0.177627
# Epoch 370, loss=0.177575
# Epoch 371, loss=0.177524
# Epoch 372, loss=0.177474
# Epoch 373, loss=0.177425
# Epoch 374, loss=0.177376
# Epoch 375, loss=0.177328
# Epoch 376, loss=0.177281
# Epoch 377, loss=0.177234
# Epoch 378, loss=0.177188
# Epoch 379, loss=0.177143
# Epoch 380, loss=0.177098
# Epoch 381, loss=0.177054
# Epoch 382, loss=0.177011
# Epoch 383, loss=0.176969
# Epoch 384, loss=0.176926
# Epoch 385, loss=0.176885
# Epoch 386, loss=0.176844
# Epoch 387, loss=0.176804
# Epoch 388, loss=0.176764
# Epoch 389, loss=0.176725
# Epoch 390, loss=0.176687
# Epoch 391, loss=0.176649
# Epoch 392, loss=0.176611
# Epoch 393, loss=0.176575
# Epoch 394, loss=0.176538
# Epoch 395, loss=0.176503
# Epoch 396, loss=0.176467
# Epoch 397, loss=0.176433
# Epoch 398, loss=0.176398
# Epoch 399, loss=0.176365
# Epoch 400, loss=0.176332
# Epoch 401, loss=0.176299
# Epoch 402, loss=0.176267
# Epoch 403, loss=0.176235
# Epoch 404, loss=0.176204
# Epoch 405, loss=0.176173
# Epoch 406, loss=0.176142
# Epoch 407, loss=0.176113
# Epoch 408, loss=0.176083
# Epoch 409, loss=0.176054
# Epoch 410, loss=0.176025
# Epoch 411, loss=0.175997
# Epoch 412, loss=0.175970
# Epoch 413, loss=0.175942
# Epoch 414, loss=0.175915
# Epoch 415, loss=0.175889
# Epoch 416, loss=0.175863
# Epoch 417, loss=0.175837
# Epoch 418, loss=0.175811
# Epoch 419, loss=0.175786
# Epoch 420, loss=0.175762
# Epoch 421, loss=0.175738
# Epoch 422, loss=0.175714
# Epoch 423, loss=0.175690
# Epoch 424, loss=0.175667
# Epoch 425, loss=0.175644
# Epoch 426, loss=0.175622
# Epoch 427, loss=0.175600
# Epoch 428, loss=0.175578
# Epoch 429, loss=0.175556
# Epoch 430, loss=0.175535
# Epoch 431, loss=0.175514
# Epoch 432, loss=0.175494
# Epoch 433, loss=0.175473
# Epoch 434, loss=0.175453
# Epoch 435, loss=0.175434
# Epoch 436, loss=0.175415
# Epoch 437, loss=0.175396
# Epoch 438, loss=0.175377
# Epoch 439, loss=0.175358
# Epoch 440, loss=0.175340
# Epoch 441, loss=0.175322
# Epoch 442, loss=0.175304
# Epoch 443, loss=0.175287
# Epoch 444, loss=0.175270
# Epoch 445, loss=0.175253
# Epoch 446, loss=0.175237
# Epoch 447, loss=0.175220
# Epoch 448, loss=0.175204
# Epoch 449, loss=0.175188
# Epoch 450, loss=0.175172
# Epoch 451, loss=0.175157
# Epoch 452, loss=0.175142
# Epoch 453, loss=0.175127
# Epoch 454, loss=0.175112
# Epoch 455, loss=0.175098
# Epoch 456, loss=0.175084
# Epoch 457, loss=0.175069
# Epoch 458, loss=0.175056
# Epoch 459, loss=0.175042
# Epoch 460, loss=0.175029
# Epoch 461, loss=0.175015
# Epoch 462, loss=0.175002
# Epoch 463, loss=0.174990
# Epoch 464, loss=0.174977
# Epoch 465, loss=0.174965
# Epoch 466, loss=0.174952
# Epoch 467, loss=0.174940
# Epoch 468, loss=0.174928
# Epoch 469, loss=0.174917
# Epoch 470, loss=0.174905
# Epoch 471, loss=0.174894
# Epoch 472, loss=0.174883
# Epoch 473, loss=0.174872
# Epoch 474, loss=0.174861
# Epoch 475, loss=0.174850
# Epoch 476, loss=0.174840
# Epoch 477, loss=0.174829
# Epoch 478, loss=0.174819
# Epoch 479, loss=0.174809
# Epoch 480, loss=0.174799
# Epoch 481, loss=0.174789
# Epoch 482, loss=0.174780
# Epoch 483, loss=0.174770
# Epoch 484, loss=0.174761
# Epoch 485, loss=0.174752
# Epoch 486, loss=0.174743
# Epoch 487, loss=0.174734
# Epoch 488, loss=0.174725
# Epoch 489, loss=0.174717
# Epoch 490, loss=0.174708
# Epoch 491, loss=0.174700
# Epoch 492, loss=0.174692
# Epoch 493, loss=0.174684
# Epoch 494, loss=0.174676
# Epoch 495, loss=0.174668
# Epoch 496, loss=0.174660
# Epoch 497, loss=0.174653
# Epoch 498, loss=0.174645
# Epoch 499, loss=0.174638
# Epoch 500, loss=0.174630
# Epoch 501, loss=0.174623
# Epoch 502, loss=0.174616
# Epoch 503, loss=0.174609
# Epoch 504, loss=0.174603
# Epoch 505, loss=0.174596
# Epoch 506, loss=0.174589
# Epoch 507, loss=0.174583
# Epoch 508, loss=0.174576
# Epoch 509, loss=0.174570
# Epoch 510, loss=0.174564
# Epoch 511, loss=0.174558
# Epoch 512, loss=0.174552
# Epoch 513, loss=0.174546
# Epoch 514, loss=0.174540
# Epoch 515, loss=0.174534
# Epoch 516, loss=0.174528
# Epoch 517, loss=0.174523
# Epoch 518, loss=0.174517
# Epoch 519, loss=0.174512
# Epoch 520, loss=0.174507
# Epoch 521, loss=0.174501
# Epoch 522, loss=0.174496
# Epoch 523, loss=0.174491
# Epoch 524, loss=0.174486
# Epoch 525, loss=0.174481
# Epoch 526, loss=0.174476
# Epoch 527, loss=0.174472
# Epoch 528, loss=0.174467
# Epoch 529, loss=0.174462
# Epoch 530, loss=0.174458
# Epoch 531, loss=0.174453
# Epoch 532, loss=0.174449
# Epoch 533, loss=0.174445
# Epoch 534, loss=0.174440
# Epoch 535, loss=0.174436
# Epoch 536, loss=0.174432
# Epoch 537, loss=0.174428
# Epoch 538, loss=0.174424
# Epoch 539, loss=0.174420
# Epoch 540, loss=0.174416
# Epoch 541, loss=0.174412
# Epoch 542, loss=0.174408
# Epoch 543, loss=0.174404
# Epoch 544, loss=0.174401
# Epoch 545, loss=0.174397
# Epoch 546, loss=0.174393
# Epoch 547, loss=0.174390
# Epoch 548, loss=0.174386
# Epoch 549, loss=0.174383
# Epoch 550, loss=0.174380
# Epoch 551, loss=0.174376
# Epoch 552, loss=0.174373
# Epoch 553, loss=0.174370
# Epoch 554, loss=0.174367
# Epoch 555, loss=0.174364
# Epoch 556, loss=0.174361
# Epoch 557, loss=0.174358
# Epoch 558, loss=0.174355
# Epoch 559, loss=0.174352
# Epoch 560, loss=0.174350
# Epoch 561, loss=0.174347
# Epoch 562, loss=0.174344
# Epoch 563, loss=0.174341
# Epoch 564, loss=0.174339
# Epoch 565, loss=0.174336
# Epoch 566, loss=0.174334
# Epoch 567, loss=0.174331
# Epoch 568, loss=0.174328
# Epoch 569, loss=0.174326
# Epoch 570, loss=0.174323
# Epoch 571, loss=0.174321
# Epoch 572, loss=0.174319
# Epoch 573, loss=0.174316
# Epoch 574, loss=0.174314
# Epoch 575, loss=0.174312
# Epoch 576, loss=0.174309
# Epoch 577, loss=0.174307
# Epoch 578, loss=0.174305
# Epoch 579, loss=0.174303
# Epoch 580, loss=0.174300
# Epoch 581, loss=0.174298
# Epoch 582, loss=0.174296
# Epoch 583, loss=0.174294
# Epoch 584, loss=0.174292
# Epoch 585, loss=0.174290
# Epoch 586, loss=0.174288
# Epoch 587, loss=0.174286
# Epoch 588, loss=0.174284
# Epoch 589, loss=0.174282
# Epoch 590, loss=0.174281
# Epoch 591, loss=0.174279
# Epoch 592, loss=0.174277
# Epoch 593, loss=0.174275
# Epoch 594, loss=0.174274
# Epoch 595, loss=0.174272
# Epoch 596, loss=0.174271
# Epoch 597, loss=0.174269
# Epoch 598, loss=0.174268
# Epoch 599, loss=0.174266

# %% [markdown]
# ##Error plot

# %%
plt.xlabel('epochs')
plt.ylabel('Mean Squared Error')
plt.loglog(epochs,loss_total)

# %% [markdown]
# ##Testing on new functions

# %%
#prediction for a-new function, test new data preparation
A_new=np.random.rand()
B_new=np.random.rand()
X_test_branch=[]
X_test_trunck=[]

f_new=fn(A_new,B_new,x_sensor)
for i in range(1):
    for j in range(n_train):
        X_test_branch.append(f_new)
        X_test_trunck.append(y[j])

#testing data
X_test_branch=np.array(X_test_branch)
X_test_trunck=np.array(X_test_trunck)

#new unseen function pred
s=model([X_test_branch, X_test_trunck])
pred=tf.reshape(s,(nx,nt))

fig, axes = plt.subplots(1, 2, figsize=(16, 4))

# First set of plots
ax1 = axes[0]
ax1.set_title('PI-DeepOnet Prediction')
im1 = ax1.imshow(pred, cmap='jet', origin='lower')
fig.colorbar(im1, orientation='vertical')

# Second set of plots
ax2 = axes[1]
ax2.set_title('Numerical solution')
x = np.linspace(0, 1, nx)
t = np.linspace(0, 1, nt)
u_inp_fun = fn(A_new, B_new, x)
sol_fun = sol_reaction_diff(u_inp_fun, t, K_coeff, D_coeff)
im2 = ax2.imshow(sol_fun, cmap='jet', origin='lower')
fig.colorbar(im2, orientation='vertical')

plt.show()

# %% [markdown]
# ##Mean Squared error of the PI-DeepOnet solution for the new function

# %%
np.mean((pred-sol_fun)**2)
# Out:
# 0.012425973

# %% [markdown]
# ##**R2 Scores of the prediction**

# %%
r2=1-(np.sum((pred-sol_fun)**2)/(np.sum((sol_fun-np.mean(sol_fun))**2)))
print(r2)
# Out:
# 0.9238773691125235

# %% [markdown]
# ##Test on 1000 new functions

# %%
r2_scores=[]
for i in range(500):
    A_new=np.random.rand()
    B_new=np.random.rand()
    X_test_branch=[]
    X_test_trunck=[]

    f_new=fn(A_new,B_new,x_sensor)
    for k in range(1):
        for j in range(n_train):
            X_test_branch.append(f_new)
            X_test_trunck.append(y[j])

      #testing data
    X_test_branch=np.array(X_test_branch)
    X_test_trunck=np.array(X_test_trunck)

      #new unseen function pred
    s=model([X_test_branch, X_test_trunck])
    pred=tf.reshape(s,(nx,nt))

  #numerical sol for the test function
    x=np.linspace(0,1,nx)
    t=np.linspace(0,1,nt)
    u_inp_fun=fn(A_new,B_new,x)
    sol_fun =  sol_reaction_diff(u_inp_fun,t,K_coeff,D_coeff)
    r2=1-(np.sum((pred-sol_fun)**2)/(np.sum((sol_fun-np.mean(sol_fun))**2)))
    r2_scores.append(r2)
    
    if(i%100==0):
        print(i/100)
        fig, axes = plt.subplots(1, 2, figsize=(16, 4))

        # First set of plots
        ax1 = axes[0]
        ax1.set_title('PI-DeepOnet Prediction')
        im1 = ax1.imshow(pred, cmap='jet', origin='lower')
        fig.colorbar(im1, orientation='vertical')

        # Second set of plots
        ax2 = axes[1]
        ax2.set_title('Numerical solution')
        x = np.linspace(0, 1, nx)
        t = np.linspace(0, 1, nt)
        u_inp_fun = fn(A_new, B_new, x)
        sol_fun = sol_reaction_diff(u_inp_fun, t, K_coeff, D_coeff)
        im2 = ax2.imshow(sol_fun, cmap='jet', origin='lower')
        fig.colorbar(im2, orientation='vertical')

        plt.show()
# Out:
# 0.0
# 1.0
# 2.0
# 3.0
# 4.0

# %%
plt.xlabel('nth function')
plt.ylabel('R2 Scores')
plt.scatter(np.arange(len(r2_scores)),r2_scores)

# %%
#observation-mean r2 score increases with #of functions
avg_r2=np.sum(np.array(r2_scores))/len(r2_scores)
print(avg_r2)
# Out:
# 0.9011812109517189

# %%
def new_fn(A,B,x):
    return 0.345

#prediction for a-new function, test new data preparation
A_new=np.random.rand()
B_new=np.random.rand()
X_test_branch=[]
X_test_trunck=[]

f_new=fn(A_new,B_new,x_sensor)
for i in range(1):
    for j in range(n_train):
        X_test_branch.append(f_new)
        X_test_trunck.append(y[j])

#testing data
X_test_branch=np.array(X_test_branch)
X_test_trunck=np.array(X_test_trunck)

#new unseen function pred
s=model([X_test_branch, X_test_trunck])
pred=tf.reshape(s,(nx,nt))

fig = plt.figure(figsize=(16,4))
ax1 = fig.add_subplot(121)
ax1.set_title('PI-DeepOnet Prediction')
im1 = ax1.imshow(pred,cmap='jet',origin='lower')
fig.colorbar(im1, orientation='vertical')

#numerical sol for the test function
x=np.linspace(0,1,nx)
t=np.linspace(0,1,nt)
u_inp_fun=fn(A_new,B_new,x)
sol_fun =  sol_reaction_diff(u_inp_fun,t,K_coeff,D_coeff)

#plot the results
fig2 = plt.figure(figsize=(16,4))
ax2 = fig2.add_subplot(121)
ax2.set_title('Numerical solution')
im2 = ax2.imshow(sol_fun,cmap='jet',origin='lower')
fig2.colorbar(im2, orientation='vertical')
plt.show()

# %%
r2=1-(np.sum((pred-sol_fun)**2)/(np.sum((sol_fun-np.mean(sol_fun))**2)))
print(r2)
# Out:
# 0.9001271352491074

# %%
#add different types of fnx in training
#PINN comparision
